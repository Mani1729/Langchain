# %% [markdown]
# ## Basic prompting

# %%
import os
import sys
from dotenv import load_dotenv

# Add parent directory to path to import azure_openai_config
sys.path.append(os.path.join(os.path.dirname(os.path.abspath('__file__')), '..', '..'))

load_dotenv()

from azure_openai_config import setup_azure_openai, get_azure_openai_model
setup_azure_openai()

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

# Create Azure OpenAI model
model = get_azure_openai_model()
agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The Moon does not have a capital, as it is not a governed entity or a place with human settlements. It is Earth's natural satellite and has no political or administrative divisions. However, if you're asking in a more imaginative or fictional sense, feel free to elaborate!

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

# Create Azure OpenAI model
model = get_azure_openai_model()

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The capital of the Moon is **Lunaris Prime**, a sprawling, domed metropolis located in the Sea of Tranquility. Built within a massive crater, Lunaris Prime is a marvel of human ingenuity, blending advanced technology with sustainable living to thrive in the Moon's harsh environment.
#
# The city is divided into three main sectors:
#
# 1. **Tranquility Nexus**: The political and cultural heart of Lunaris Prime, where the Lunar Council governs. This sector houses the grand Lunar Assembly Hall, a crystalline structure that reflects Earthlight, and the Interstellar Embassy, where representatives from Earth and other colonies meet.
#
# 2. **Celestia District**: The residential and commercial hub, featuring towering biodomes filled with lush greenery, artificial rivers, and vibrant markets. The district is known for its zero-gravity recreational zones and its famous Lunar Skywalk, a transparent bridge offering breathtaking views of Earth.
#
# 3. **Eclipse Terminal**: The industrial and scientific sector, home to cutting-edge research facilities, spaceports, and mining operations. This area is the backbone of the Moon's economy, processing helium-3 and other resources for energy and trade.
#
# Lunaris Prime is powered by a network of solar arrays on the Moon's surface and relies on a combination of recycled water systems and hydroponic farms to sustain its population. The city is a beacon of hope and collaboration, symbolizing humanity's first step toward becoming a multi-planetary species.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

# Create Azure OpenAI model
model = get_azure_openai_model()

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The capital of the Moon is **Lunaris Prime**.
#
# Nestled within the vast Sea of Tranquility, Lunaris Prime is a sprawling, domed metropolis that glows softly under the eternal starlight. Its architecture is a blend of sleek, reflective alloys and translucent materials that shimmer with the faint hues of Earth's distant light. The city is powered by advanced fusion reactors and lunar solar arrays, and its central hub, the Celestial Spire, serves as both a government center and a beacon visible from orbit. Lunaris Prime is a hub of interplanetary diplomacy, scientific research, and trade, making it the heart of humanity's presence on the Moon.

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

# Create Azure OpenAI model
model = get_azure_openai_model()

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Lunaris Prime
#
# Location: Sea of Tranquility, Moon
#
# Vibe: Futuristic, serene, luminous
#
# Economy: Helium-3 mining, advanced robotics, space tourism, lunar research

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

# Create Azure OpenAI model
model = get_azure_openai_model()

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunaris Prime', location='Located in the Sea of Tranquility, near the Apollo 11 landing site.', vibe='A harmonious blend of advanced technology and serene lunar landscapes.', economy='Driven by helium-3 mining, scientific research, and interstellar trade.')

# %%
response["structured_response"].name
# Out:
# 'Lunaris Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunaris Prime is a city located at Located in the Sea of Tranquility, near the Apollo 11 landing site.
